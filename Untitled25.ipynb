# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
import numpy as np
import seaborn as sns

import pandas as pd
from sklearn import datasets, linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
train_center=pd.read_csv('D:\\DataScience\\Foodmart\\train_GzS76OK\\fulfilment_center_info.csv')

# %%
train_meal=pd.read_csv('D:\\DataScience\\Foodmart\\train_GzS76OK\\meal_info.csv')

# %%
train=pd.read_csv('D:\\DataScience\\Foodmart\\train_GzS76OK\\train.csv')

# %%
test=pd.read_csv('D:\\DataScience\\Foodmart\\test_QoiMO9B.csv')

# %%
submission=pd.read_csv('D:\\DataScience\\Foodmart\\sample_submission_hSlSoT6.csv')
submission.head()
# Out:
#         id  num_orders
# 0  1028232           0
# 1  1127204           0
# 2  1212707           0
# 3  1082698           0
# 4  1400926           0

# %%
train.shape
# Out:
# (456548, 9)

# %%
train_meal.shape
# Out:
# (51, 3)

# %%
train_center.shape
# Out:
# (77, 5)

# %%
train
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1         55     1885          136.83      152.29
# 1  1466964     1         55     1993          136.83      135.83
# 2  1346989     1         55     2539          134.86      135.86
# 3  1338232     1         55     2139          339.50      437.53
# 4  1448490     1         55     2631          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders
# 0                      0                  0         177
# 1                      0                  0         270
# 2                      0                  0         189
# 3                      0                  0          54
# 4                      0                  0          40

# %%
train_center[train_center['center_id'] ==55]
# Out:
#     center_id  city_code  region_code center_type  op_area
# 27         55        647           56      TYPE_C      2.0

# %%
train_meal.head()
# Out:
#    meal_id   category cuisine
# 0     1885  Beverages    Thai
# 1     1993  Beverages    Thai
# 2     2539  Beverages    Thai
# 3     1248  Beverages  Indian
# 4     2631  Beverages  Indian

# %%
train_comb1=pd.merge(train,train_center,how='inner', on=['center_id', 'center_id'])

# %%
train_comb_final=pd.merge(train_comb1,train_meal,how='inner', on=['meal_id', 'meal_id'])

# %%
train_comb_final.corr()
# Out:
#                              id      week  center_id   meal_id  \
# id                     1.000000  0.002225   0.002641  0.000488
# week                   0.002225  1.000000  -0.003450  0.019814
# center_id              0.002641 -0.003450   1.000000  0.009893
# meal_id                0.000488  0.019814   0.009893  1.000000
# checkout_price         0.001941  0.026581   0.001348  0.010748
# base_price             0.002909  0.028614   0.000604  0.002605
# emailer_for_promotion  0.002001 -0.000841   0.013658  0.013402
# homepage_featured      0.003111 -0.008263  -0.005043  0.016354
# num_orders             0.000702 -0.017210  -0.053035  0.010597
# city_code             -0.000387  0.000405   0.061078 -0.003198
# region_code           -0.000648  0.004600  -0.003426 -0.001662
# op_area               -0.000090  0.001550  -0.111869 -0.001546
#
#                        checkout_price  base_price  emailer_for_promotion  \
# ...

# %%
sns.heatmap(train.corr(),annot=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456548 entries, 0 to 456547
# Data columns (total 9 columns):
# id                       456548 non-null int64
# week                     456548 non-null int64
# center_id                456548 non-null int64
# meal_id                  456548 non-null int64
# checkout_price           456548 non-null float64
# base_price               456548 non-null float64
# emailer_for_promotion    456548 non-null int64
# homepage_featured        456548 non-null int64
# num_orders               456548 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 31.3 MB

# %%
sns.pairplot(train_comb_final)

# %%
train_comb_final.query('week==1  and center_id ==55  and meal_id==1885' )
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1         55     1885          136.83      152.29
#
#    emailer_for_promotion  homepage_featured  num_orders  city_code  \
# 0                      0                  0         177        647
#
#    region_code center_type  op_area   category cuisine
# 0           56      TYPE_C      2.0  Beverages    Thai

# %%
train_comb_final.query('checkout_price==866.27')
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 273770  1213267   135         93     1445          866.27      866.27
#
#         emailer_for_promotion  homepage_featured  num_orders  city_code  \
# 273770                      0                  0          94        461
#
#         region_code center_type  op_area category      cuisine
# 273770           34      TYPE_A      3.9  Seafood  Continental

# %%
train_comb_final.groupby(['center_type','category'])['checkout_price']
# Out:
# center_type  category
# TYPE_A       Beverages       213.134941
#              Biryani         450.011451
#              Desert          437.202807
#              Extras          171.896435
#              Fish            579.447137
#              Other Snacks    258.211053
#              Pasta           395.153805
#              Pizza           583.784609
#              Rice Bowl       315.947330
#              Salad           290.872241
#              Sandwich        289.937213
#              Seafood         611.777997
#              Soup            223.405527
#              Starters        278.438293
# TYPE_B       Beverages       214.308960
#              Biryani         451.038930
#              Desert          438.532825
#              Extras          171.524786
#              Fish            580.192647
#              Other Snacks    258.567465
#              Pasta           395.202179
#              Pizza           583.829552
#              Rice Bowl       318.945887
# ...

# %%
train_comb_final['checkout_price'].plot(kind='box')

# %%
train_comb_final['base_price'].plot(kind='box')

# %%
train_comb_final['num_orders'].plot(kind='box')

# %%
train_comb_final[train_comb_final['num_orders'] > 20000]
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 137437  1452474     5         43     2290          159.08      311.43
#
#         emailer_for_promotion  homepage_featured  num_orders  city_code  \
# 137437                      1                  1       24299        590
#
#         region_code center_type  op_area   category cuisine
# 137437           56      TYPE_A      5.1  Rice Bowl  Indian

# %%
plt.xlim(1000,3000)
train_comb_final['meal_id'].plot(kind='hist',bins=10)

# %%
train_comb_final['meal_id'].describe()
# Out:
# count    456548.000000
# mean       2024.337458
# std         547.420920
# min        1062.000000
# 25%        1558.000000
# 50%        1993.000000
# 75%        2539.000000
# max        2956.000000
# Name: meal_id, dtype: float64

# %%
train_comb_final['checkout_price'].max()
# Out:
# 866.27

# %%
train_comb_final.emailer_for_promotion.value_counts()
# Out:
# 0    419498
# 1     37050
# Name: emailer_for_promotion, dtype: int64

# %%
train_comb_final.homepage_featured.value_counts()
# Out:
# 0    406693
# 1     49855
# Name: homepage_featured, dtype: int64

# %%
train_comb_final.query('num_orders==0')
# Out:
# Empty DataFrame
# Columns: [id, week, center_id, meal_id, checkout_price, base_price, emailer_for_promotion, homepage_featured, num_orders, city_code, region_code, center_type, op_area, category, cuisine]
# Index: []

# %%
train_comb_final.drop(columns=['id','center_id','meal_id'],inplace=True)

# %%
train_comb_final.head()
# Out:
#    week  checkout_price  base_price  emailer_for_promotion  homepage_featured  \
# 0     1          136.83      152.29                      0                  0
# 1     2          135.83      152.29                      0                  0
# 2     3          132.92      133.92                      0                  0
# 3     4          135.86      134.86                      0                  0
# 4     5          146.50      147.50                      0                  0
#
#    num_orders  city_code  region_code center_type  op_area   category cuisine
# 0         177        647           56      TYPE_C      2.0  Beverages    Thai
# 1         323        647           56      TYPE_C      2.0  Beverages    Thai
# 2          96        647           56      TYPE_C      2.0  Beverages    Thai
# 3         163        647           56      TYPE_C      2.0  Beverages    Thai
# 4         215        647           56      TYPE_C      2.0  Beverages    Thai

# %%
X= train.drop(columns='num_orders')
y=train['num_orders']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
y_train_predictions = lm.predict(X_train)
y_test_predictions = lm.predict(X_test)

# %%
metrics.r2_score(y_train,y_train_predictions)
# Out:
# 0.1936770960828138

# %%
metrics.r2_score(y_test,y_test_predictions)
# Out:
# 0.2038373343846439
