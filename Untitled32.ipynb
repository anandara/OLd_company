# %%
from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
from random import randrange

#The seasonal_decompose() function returns a result object. The result object contains arrays to access four pieces 
#of data from the decomposition

# %% [markdown]
# # Addtiive Model
# y(t) = Level + Trend + Seasonality + Noise
# additive model is linear where changes over time are consistently made by the same amount.
# A linear trend is a straight line.
# A linear seasonality has the same frequency (width of cycles) and amplitude (height of cycles).

# %%
series = [i+randrange(10) for i in range(1,100)]
result = seasonal_decompose(series, model='additive', freq=1)
result.plot()
pyplot.show()

# %% [markdown]
# # #Multiplicative Model
# multiplicative model is nonlinear, such as quadratic or exponential. Changes increase or decrease over time.
# A nonlinear trend is a curved line.
# A non-linear seasonality has an increasing or decreasing frequency and/or amplitude over time.

# %%
series = [i**2.0 for i in range(1,100)]
result = seasonal_decompose(series, model='multiplicative', freq=1)
result.plot()
pyplot.show()
